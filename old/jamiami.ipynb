# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import os

# %%
basedir = '.'

file_dir = os.path.join(basedir,r'Jamay\Jamay_RiberadeChapala_2016_UTM.shp') 


df = gpd.read_file(file_dir)
df['TIPO'].unique()
df[df['TEMA'] != 'INFRAESTRUCTURA DE SERVICIOS']
df
# Out:
#      ID_IIEG   ID_DENUE  CÓDIGO_SC                          TEMA  \
# 0     1782.0  1648223.0   722511.0          ESTRUCTURA TURISTÍCA
# 1     1783.0  1649519.0   722511.0          ESTRUCTURA TURISTÍCA
# 2     1784.0  1732596.0   722511.0          ESTRUCTURA TURISTÍCA
# 3     1785.0  1649699.0   722511.0          ESTRUCTURA TURISTÍCA
# 4     1786.0  1649497.0   722511.0          ESTRUCTURA TURISTÍCA
# ..       ...        ...        ...                           ...
# 133   1915.0  9999999.0   517110.0  INFRAESTRUCTURA DE SERVICIOS
# 134   1916.0  9999999.0   517110.0  INFRAESTRUCTURA DE SERVICIOS
# 135   1917.0  9999999.0   713113.0         ATRACTIVOS TURÍSTICOS
# 136   1918.0  9999999.0   713113.0         ATRACTIVOS TURÍSTICOS
# 137   1919.0  9999999.0   485210.0  INFRAESTRUCTURA DE SERVICIOS
#
#                   CATEGORÍA  TIPO                SUBTIPO  \
# 0    ALIMENTACIÓN Y BEBIDAS  None              NO APLICA
# 1    ALIMENTACIÓN Y BEBIDAS  None              NO APLICA
# ...

# %%
fig,ax = plt.subplots()

df.plot(
    categorical = True,
    legend = True,
    ax = ax,
    column = 'MUNICIPIO'
)
plt.show()
