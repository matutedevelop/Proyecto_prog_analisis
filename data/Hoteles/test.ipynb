# %%
import pandas as pd

# %%
pd.read_csv('Hoteles_2019.csv')
# Out:
#      Unnamed: 0              municipio  total  5 estrellas  4 estrellas  \
# 0             7              Municipio   2205          179          293
# 1             9                 ACATIC      4            0            0
# 2            10      ACATLÁN DE JUÁREZ      1            0            0
# 3            11   AHUALULCO DE MERCADO      9            1            3
# 4            12               AMACUECA      1            0            0
# ..          ...                    ...    ...          ...          ...
# 104         122             ZAPOTILTIC      5            0            1
# 105         123  ZAPOTITLÁN DE VADILLO      1            0            0
# 106         124       ZAPOTLÁN DEL REY      2            1            0
# 107         125     ZAPOTLÁN EL GRANDE     18            0            2
# 108         126            ZAPOTLANEJO     13            0            1
#
#      3 estrellas  2 estrellas  1 estrellas  sin categoria   año
# ...
